# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# col_names = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'label']


pima = pd.read_csv("diabetes.csv")


pima.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
feature_cols = ['Pregnancies','Insulin','BMI','Age','Glucose','BloodPressure','DiabetesPedigreeFunction']
X= pima[feature_cols]
y= pima.Outcome

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)


cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.show()


print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
print("F1_Score:",metrics.f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.670995670995671
# Precision: 0.56
# Recall: 0.49411764705882355
# F1_Score: 0.525

# %%
from sklearn.tree import export_graphviz
from io import StringIO
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     852 try:
# --> 853     loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854 except IndexError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4703, in ParseElementEnhance.parseImpl(self, instring, loc, do_actions)
#    4702 try:
# -> 4703     return self.expr._parse(instring, loc, do_actions, callPreParse=False)
#    4704 except ParseSyntaxException:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     852 try:
# --> 853     loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854 except IndexError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4175, in And.parseImpl(self, instring, loc, do_actions)
#    4172 def parseImpl(self, instring, loc, do_actions=True):
#    4173     # pass False as callPreParse arg to _parse for first element, since we already
#    4174     # pre-parsed the string as part of our And pre-parsing
# -> 4175     loc, resultlist = self.exprs[0]._parse(
#    4176         instring, loc, do_actions, callPreParse=False
#    4177     )
#    4178     errorStop = False
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:857, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     856     else:
# --> 857         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     859 tokens = self.postParse(instring, loc, tokens)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:2504, in _SingleCharLiteral.parseImpl(self, instring, loc, do_actions)
#    2503     return loc + 1, self.match
# -> 2504 raise ParseException(instring, loc, self.errmsg, self)
#
# ParseException: Expected '#', found 'br'  (at char 15181), (line:247, col:24)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 10
#       6 dot_data = StringIO()
#       7 export_graphviz(clf, out_file=dot_data,
#       8                 filled=True, rounded=True,
#       9                 special_characters=True,feature_names = feature_cols,class_names=['0','1'])
# ---> 10 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
#      11 graph.write_png('diabetes.png')
#      12 Image(graph.create_png())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pydotplus\graphviz.py:302, in graph_from_dot_data(data)
#     294 def graph_from_dot_data(data):
#     295     """Load graph as defined by data in DOT format.
#     296
#     297     The data is assumed to be in DOT format. It will
#     298     be parsed and a Dot class will be returned,
#     299     representing the graph.
#     300     """
# --> 302     return parser.parse_dot_data(data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pydotplus\parser.py:558, in parse_dot_data(data)
#     555 if pyparsing_version >= '1.2':
#     556     graphparser.parseWithTabs()
# --> 558 tokens = graphparser.parseString(data)
#     560 if len(tokens) == 1:
#     561     return tokens[0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\util.py:417, in replaced_by_pep8.<locals>._inner(self, *args, **kwargs)
#     412 @wraps(fn)
#     413 def _inner(self, *args, **kwargs):
#     414     # warnings.warn(
#     415     #     f"Deprecated - use {fn.__name__}", DeprecationWarning, stacklevel=2
#     416     # )
# --> 417     return fn(self, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:1207, in ParserElement.parse_string(self, instring, parse_all, parseAll)
#    1205     instring = instring.expandtabs()
#    1206 try:
# -> 1207     loc, tokens = self._parse(instring, 0)
#    1208     if parseAll:
#    1209         loc = self.preParse(instring, loc)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:5131, in _MultipleMatch.parseImpl(self, instring, loc, do_actions)
#    5129 if check_ender:
#    5130     try_not_ender(instring, loc)
# -> 5131 loc, tokens = self_expr_parse(instring, loc, do_actions)
#    5132 try:
#    5133     hasIgnoreExprs = not not self.ignoreExprs
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4197, in And.parseImpl(self, instring, loc, do_actions)
#    4193             raise ParseSyntaxException(
#    4194                 instring, len(instring), self.errmsg, self
#    4195             )
#    4196     else:
# -> 4197         loc, exprtokens = e._parse(instring, loc, do_actions)
#    4198     resultlist += exprtokens
#    4199 return loc, resultlist
#
#     [... skipping similar frames: ParserElement._parseCache at line 991 (1 times), ParserElement._parseNoCache at line 853 (1 times)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4703, in ParseElementEnhance.parseImpl(self, instring, loc, do_actions)
#    4700     raise ParseException(instring, loc, "No expression defined", self)
#    4702 try:
# -> 4703     return self.expr._parse(instring, loc, do_actions, callPreParse=False)
#    4704 except ParseSyntaxException:
#    4705     raise
#
#     [... skipping similar frames: ParserElement._parseCache at line 991 (1 times), ParserElement._parseNoCache at line 853 (1 times)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4197, in And.parseImpl(self, instring, loc, do_actions)
#    4193             raise ParseSyntaxException(
#    4194                 instring, len(instring), self.errmsg, self
#    4195             )
#    4196     else:
# -> 4197         loc, exprtokens = e._parse(instring, loc, do_actions)
#    4198     resultlist += exprtokens
#    4199 return loc, resultlist
#
#     [... skipping similar frames: ParserElement._parseCache at line 991 (1 times), ParserElement._parseNoCache at line 853 (1 times)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:5366, in Opt.parseImpl(self, instring, loc, do_actions)
#    5364 self_expr = self.expr
#    5365 try:
# -> 5366     loc, tokens = self_expr._parse(
#    5367         instring, loc, do_actions, callPreParse=False
#    5368     )
#    5369 except (ParseException, IndexError):
#    5370     default_value = self.defaultValue
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:5666, in Forward.parseImpl(self, instring, loc, do_actions)
#    5660     warnings.warn(
#    5661         "warn_on_parse_using_empty_Forward:"
#    5662         " Forward expression was never assigned a value, will not parse any input",
#    5663         stacklevel=stacklevel,
#    5664     )
#    5665 if not ParserElement._left_recursion_enabled:
# -> 5666     return super().parseImpl(instring, loc, do_actions)
#    5667 # ## Bounded Recursion algorithm ##
#    5668 # Recursion only needs to be processed at ``Forward`` elements, since they are
#    5669 # the only ones that can actually refer to themselves. The general idea is
#    (...)   5684 # we expand using `do_actions=False` and only run `do_actions=True` if the next
#    5685 # recursion level is acceptable.
#    5686 with ParserElement.recursion_lock:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4703, in ParseElementEnhance.parseImpl(self, instring, loc, do_actions)
#    4700     raise ParseException(instring, loc, "No expression defined", self)
#    4702 try:
# -> 4703     return self.expr._parse(instring, loc, do_actions, callPreParse=False)
#    4704 except ParseSyntaxException:
#    4705     raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:5141, in _MultipleMatch.parseImpl(self, instring, loc, do_actions)
#    5139         else:
#    5140             preloc = loc
# -> 5141         loc, tmptokens = self_expr_parse(instring, preloc, do_actions)
#    5142         tokens += tmptokens
#    5143 except (ParseException, IndexError):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4175, in And.parseImpl(self, instring, loc, do_actions)
#    4172 def parseImpl(self, instring, loc, do_actions=True):
#    4173     # pass False as callPreParse arg to _parse for first element, since we already
#    4174     # pre-parsed the string as part of our And pre-parsing
# -> 4175     loc, resultlist = self.exprs[0]._parse(
#    4176         instring, loc, do_actions, callPreParse=False
#    4177     )
#    4178     errorStop = False
#    4179     for e in self.exprs[1:]:
#    4180         # if isinstance(e, And._ErrorStop):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4431, in MatchFirst.parseImpl(self, instring, loc, do_actions)
#    4429 for e in self.exprs:
#    4430     try:
# -> 4431         return e._parse(instring, loc, do_actions)
#    4432     except ParseFatalException as pfe:
#    4433         pfe.__traceback__ = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4197, in And.parseImpl(self, instring, loc, do_actions)
#    4193             raise ParseSyntaxException(
#    4194                 instring, len(instring), self.errmsg, self
#    4195             )
#    4196     else:
# -> 4197         loc, exprtokens = e._parse(instring, loc, do_actions)
#    4198     resultlist += exprtokens
#    4199 return loc, resultlist
#
#     [... skipping similar frames: ParserElement._parseCache at line 991 (1 times), ParserElement._parseNoCache at line 853 (1 times)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:5366, in Opt.parseImpl(self, instring, loc, do_actions)
#    5364 self_expr = self.expr
#    5365 try:
# -> 5366     loc, tokens = self_expr._parse(
#    5367         instring, loc, do_actions, callPreParse=False
#    5368     )
#    5369 except (ParseException, IndexError):
#    5370     default_value = self.defaultValue
#
#     [... skipping similar frames: ParserElement._parseCache at line 991 (1 times), ParserElement._parseNoCache at line 853 (1 times)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:5131, in _MultipleMatch.parseImpl(self, instring, loc, do_actions)
#    5129 if check_ender:
#    5130     try_not_ender(instring, loc)
# -> 5131 loc, tokens = self_expr_parse(instring, loc, do_actions)
#    5132 try:
#    5133     hasIgnoreExprs = not not self.ignoreExprs
#
#     [... skipping similar frames: ParserElement._parseCache at line 991 (1 times), ParserElement._parseNoCache at line 853 (1 times)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4197, in And.parseImpl(self, instring, loc, do_actions)
#    4193             raise ParseSyntaxException(
#    4194                 instring, len(instring), self.errmsg, self
#    4195             )
#    4196     else:
# -> 4197         loc, exprtokens = e._parse(instring, loc, do_actions)
#    4198     resultlist += exprtokens
#    4199 return loc, resultlist
#
#     [... skipping similar frames: ParserElement._parseCache at line 991 (1 times), ParserElement._parseNoCache at line 853 (1 times)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:5366, in Opt.parseImpl(self, instring, loc, do_actions)
#    5364 self_expr = self.expr
#    5365 try:
# -> 5366     loc, tokens = self_expr._parse(
#    5367         instring, loc, do_actions, callPreParse=False
#    5368     )
#    5369 except (ParseException, IndexError):
#    5370     default_value = self.defaultValue
#
#     [... skipping similar frames: ParserElement._parseCache at line 991 (1 times), ParserElement._parseNoCache at line 853 (1 times)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:5131, in _MultipleMatch.parseImpl(self, instring, loc, do_actions)
#    5129 if check_ender:
#    5130     try_not_ender(instring, loc)
# -> 5131 loc, tokens = self_expr_parse(instring, loc, do_actions)
#    5132 try:
#    5133     hasIgnoreExprs = not not self.ignoreExprs
#
#     [... skipping similar frames: ParserElement._parseCache at line 991 (2 times), ParserElement._parseNoCache at line 853 (2 times), And.parseImpl at line 4197 (1 times)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:5366, in Opt.parseImpl(self, instring, loc, do_actions)
#    5364 self_expr = self.expr
#    5365 try:
# -> 5366     loc, tokens = self_expr._parse(
#    5367         instring, loc, do_actions, callPreParse=False
#    5368     )
#    5369 except (ParseException, IndexError):
#    5370     default_value = self.defaultValue
#
#     [... skipping similar frames: ParserElement._parseCache at line 991 (1 times), ParserElement._parseNoCache at line 853 (1 times)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4197, in And.parseImpl(self, instring, loc, do_actions)
#    4193             raise ParseSyntaxException(
#    4194                 instring, len(instring), self.errmsg, self
#    4195             )
#    4196     else:
# -> 4197         loc, exprtokens = e._parse(instring, loc, do_actions)
#    4198     resultlist += exprtokens
#    4199 return loc, resultlist
#
#     [... skipping similar frames: ParserElement._parseCache at line 991 (1 times), ParserElement._parseNoCache at line 853 (1 times)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4431, in MatchFirst.parseImpl(self, instring, loc, do_actions)
#    4429 for e in self.exprs:
#    4430     try:
# -> 4431         return e._parse(instring, loc, do_actions)
#    4432     except ParseFatalException as pfe:
#    4433         pfe.__traceback__ = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:5666, in Forward.parseImpl(self, instring, loc, do_actions)
#    5660     warnings.warn(
#    5661         "warn_on_parse_using_empty_Forward:"
#    5662         " Forward expression was never assigned a value, will not parse any input",
#    5663         stacklevel=stacklevel,
#    5664     )
#    5665 if not ParserElement._left_recursion_enabled:
# -> 5666     return super().parseImpl(instring, loc, do_actions)
#    5667 # ## Bounded Recursion algorithm ##
#    5668 # Recursion only needs to be processed at ``Forward`` elements, since they are
#    5669 # the only ones that can actually refer to themselves. The general idea is
#    (...)   5684 # we expand using `do_actions=False` and only run `do_actions=True` if the next
#    5685 # recursion level is acceptable.
#    5686 with ParserElement.recursion_lock:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4703, in ParseElementEnhance.parseImpl(self, instring, loc, do_actions)
#    4700     raise ParseException(instring, loc, "No expression defined", self)
#    4702 try:
# -> 4703     return self.expr._parse(instring, loc, do_actions, callPreParse=False)
#    4704 except ParseSyntaxException:
#    4705     raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4703, in ParseElementEnhance.parseImpl(self, instring, loc, do_actions)
#    4700     raise ParseException(instring, loc, "No expression defined", self)
#    4702 try:
# -> 4703     return self.expr._parse(instring, loc, do_actions, callPreParse=False)
#    4704 except ParseSyntaxException:
#    4705     raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4197, in And.parseImpl(self, instring, loc, do_actions)
#    4193             raise ParseSyntaxException(
#    4194                 instring, len(instring), self.errmsg, self
#    4195             )
#    4196     else:
# -> 4197         loc, exprtokens = e._parse(instring, loc, do_actions)
#    4198     resultlist += exprtokens
#    4199 return loc, resultlist
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:5232, in ZeroOrMore.parseImpl(self, instring, loc, do_actions)
#    5230 def parseImpl(self, instring, loc, do_actions=True) -> ParseImplReturnType:
#    5231     try:
# -> 5232         return super().parseImpl(instring, loc, do_actions)
#    5233     except (ParseException, IndexError):
#    5234         return loc, ParseResults([], name=self.resultsName)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:5141, in _MultipleMatch.parseImpl(self, instring, loc, do_actions)
#    5139         else:
#    5140             preloc = loc
# -> 5141         loc, tmptokens = self_expr_parse(instring, preloc, do_actions)
#    5142         tokens += tmptokens
#    5143 except (ParseException, IndexError):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4431, in MatchFirst.parseImpl(self, instring, loc, do_actions)
#    4429 for e in self.exprs:
#    4430     try:
# -> 4431         return e._parse(instring, loc, do_actions)
#    4432     except ParseFatalException as pfe:
#    4433         pfe.__traceback__ = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:5666, in Forward.parseImpl(self, instring, loc, do_actions)
#    5660     warnings.warn(
#    5661         "warn_on_parse_using_empty_Forward:"
#    5662         " Forward expression was never assigned a value, will not parse any input",
#    5663         stacklevel=stacklevel,
#    5664     )
#    5665 if not ParserElement._left_recursion_enabled:
# -> 5666     return super().parseImpl(instring, loc, do_actions)
#    5667 # ## Bounded Recursion algorithm ##
#    5668 # Recursion only needs to be processed at ``Forward`` elements, since they are
#    5669 # the only ones that can actually refer to themselves. The general idea is
#    (...)   5684 # we expand using `do_actions=False` and only run `do_actions=True` if the next
#    5685 # recursion level is acceptable.
#    5686 with ParserElement.recursion_lock:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4703, in ParseElementEnhance.parseImpl(self, instring, loc, do_actions)
#    4700     raise ParseException(instring, loc, "No expression defined", self)
#    4702 try:
# -> 4703     return self.expr._parse(instring, loc, do_actions, callPreParse=False)
#    4704 except ParseSyntaxException:
#    4705     raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4703, in ParseElementEnhance.parseImpl(self, instring, loc, do_actions)
#    4700     raise ParseException(instring, loc, "No expression defined", self)
#    4702 try:
# -> 4703     return self.expr._parse(instring, loc, do_actions, callPreParse=False)
#    4704 except ParseSyntaxException:
#    4705     raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4197, in And.parseImpl(self, instring, loc, do_actions)
#    4193             raise ParseSyntaxException(
#    4194                 instring, len(instring), self.errmsg, self
#    4195             )
#    4196     else:
# -> 4197         loc, exprtokens = e._parse(instring, loc, do_actions)
#    4198     resultlist += exprtokens
#    4199 return loc, resultlist
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:5232, in ZeroOrMore.parseImpl(self, instring, loc, do_actions)
#    5230 def parseImpl(self, instring, loc, do_actions=True) -> ParseImplReturnType:
#    5231     try:
# -> 5232         return super().parseImpl(instring, loc, do_actions)
#    5233     except (ParseException, IndexError):
#    5234         return loc, ParseResults([], name=self.resultsName)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:5131, in _MultipleMatch.parseImpl(self, instring, loc, do_actions)
#    5129 if check_ender:
#    5130     try_not_ender(instring, loc)
# -> 5131 loc, tokens = self_expr_parse(instring, loc, do_actions)
#    5132 try:
#    5133     hasIgnoreExprs = not not self.ignoreExprs
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4431, in MatchFirst.parseImpl(self, instring, loc, do_actions)
#    4429 for e in self.exprs:
#    4430     try:
# -> 4431         return e._parse(instring, loc, do_actions)
#    4432     except ParseFatalException as pfe:
#    4433         pfe.__traceback__ = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:847, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     845 else:
#     846     if callPreParse and self.callPreparse:
# --> 847         pre_loc = self.preParse(instring, loc)
#     848     else:
#     849         pre_loc = loc
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:796, in ParserElement.preParse(self, instring, loc)
#     794 def preParse(self, instring: str, loc: int) -> int:
#     795     if self.ignoreExprs:
# --> 796         loc = self._skipIgnorables(instring, loc)
#     798     if self.skipWhitespace:
#     799         instrlen = len(instring)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:784, in ParserElement._skipIgnorables(self, instring, loc)
#     782 try:
#     783     while 1:
# --> 784         loc, dummy = ignore_fn(instring, loc)
#     785         exprsFound = True
#     786 except ParseException:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4703, in ParseElementEnhance.parseImpl(self, instring, loc, do_actions)
#    4700     raise ParseException(instring, loc, "No expression defined", self)
#    4702 try:
# -> 4703     return self.expr._parse(instring, loc, do_actions, callPreParse=False)
#    4704 except ParseSyntaxException:
#    4705     raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:991, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     989 ParserElement.packrat_cache_stats[MISS] += 1
#     990 try:
# --> 991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
#     994     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:853, in ParserElement._parseNoCache(self, instring, loc, do_actions, callPreParse)
#     851 if self.mayIndexError or pre_loc >= len_instring:
#     852     try:
# --> 853         loc, tokens = self.parseImpl(instring, pre_loc, do_actions)
#     854     except IndexError:
#     855         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:4431, in MatchFirst.parseImpl(self, instring, loc, do_actions)
#    4429 for e in self.exprs:
#    4430     try:
# -> 4431         return e._parse(instring, loc, do_actions)
#    4432     except ParseFatalException as pfe:
#    4433         pfe.__traceback__ = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\core.py:994, in ParserElement._parseCache(self, instring, loc, do_actions, callPreParse)
#     991     value = self._parseNoCache(instring, loc, do_actions, callPreParse)
#     992 except ParseBaseException as pe:
#     993     # cache a copy of the exception, without the traceback
# --> 994     cache.set(lookup, pe.__class__(*pe.args))
#     995     raise
#     996 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyparsing\util.py:117, in _FifoCache.__init__.<locals>.set_(_, key, value)
#     114 cache[key] = value
#     115 while len(cache) > size:
#     116     # pop oldest element in cache by getting the first key
# --> 117     cache_pop(next(iter(cache)))
#
# KeyboardInterrupt:

# %%
clf = DecisionTreeClassifier(criterion="entropy", max_depth=3)

clf = clf.fit(X_train,y_train)

y_pred = clf.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
print("F1_Score:",metrics.f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.7705627705627706
# Precision: 0.7105263157894737
# Recall: 0.6352941176470588
# F1_Score: 0.6708074534161491

# %%
from six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes.png')
Image(graph.create_png())
